# %%
import pandas as pd
import numpy as np
destDFHours = pd.read_excel('FY19 Execution - OTA 20 Mar 2019.xlsx', sheet_name = 'Hours', header = 3)
keepArray = []
nanFlag = False
print (destDFHours)
for index, row in destDFHours.iterrows():
    if row.values is np.array([None]*len(row))
#         keepArray.append(index)
        print(index)
      
    else:
        nanFlag = True
# Out:
#                      Labor Category              Company  FTE  \
# NaN              PROGRAM ANALYST VI        Analytix, LLC    1
# NaN             PROGRAM ANALYST III        Analytix, LLC    2
# NaN          ENGINEER/SCIENTIST VII  DESE Research, Inc.    1
# NaN                    ENGINEER III    nou Systems, Inc.    1
# NaN  PROGRAM SYSTEMS ANALYST III TM    nou Systems, Inc.    1
# NaN  PROGRAM SYSTEMS ANALYST VI- TM    nou Systems, Inc.    3
# NaN                 SR ENGINEER III    nou Systems, Inc.    2
# NaN                   ENGINEER VIII    nou Systems, Inc.    3
# NaN      PROGRAM SYSTEMS ANALYST IX    nou Systems, Inc.    2
# NaN         SUBJECT MATTER EXPERT I    nou Systems, Inc.    1
# NaN       PROGRAM SYSTEMS ANALYST V    nou Systems, Inc.    1
# NaN       PROGRAM SYSTEMS ANALYST I    nou Systems, Inc.    1
# NaN                             NaN                  NaN  NaN
# NaN                             NaN                  NaN  NaN
# ...
